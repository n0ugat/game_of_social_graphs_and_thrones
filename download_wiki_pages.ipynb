# %%
# Download pages in raw wiki markup format to txt files
import requests
import time
import os
import glob


# Chose an interval of pages, that haven't already been downloaded
# ==== CONFIGURATION ====
START_PAGE = 1601      # Start from this page number
END_PAGE = 2000      # End at this page number (inclusive)
OUTPUT_FOLDER = "GoT_files"


# HUSK AT BRUGE DIT NAVN!!!!!!
# The script will write worker-specific files like fetched_pages_<name>.txt
# WORKER_NAME = "mathias"
# WORKER_NAME = "nikolai"
WORKER_NAME = "sofie" 
# =======================

def get_page_wikitext(page_title):
    """Get raw wiki markup for a page"""
    url = "https://gameofthrones.fandom.com/api.php"
    
    params = {
        "action": "query",
        "prop": "revisions",
        "titles": page_title,
        "rvprop": "content",
        "format": "json",
        "rvslots": "main"
    }
    
    try:
        response = requests.get(url, params=params)
        data = response.json()
        
        page = next(iter(data["query"]["pages"].values()))
        
        # Check if page exists and has content
        if "revisions" in page:
            wikitext = page["revisions"][0]["slots"]["main"]["*"]
            return wikitext
        else:
            return None
    except Exception as e:
        print(f"    Error: {e}")
        return None

def save_wikitext_to_file(page_title, wikitext, output_dir):
    """Save wikitext to a file"""
    # Create directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Clean the filename (remove invalid characters)
    filename = page_title.replace("/", "_").replace("\\", "_").replace(":", "_")
    filename = filename.replace("?", "_").replace("*", "_").replace("|", "_")
    filename = filename.replace("<", "_").replace(">", "_").replace('"', "_")
    filepath = os.path.join(output_dir, f"{filename}.txt")
    
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(wikitext)
    
    return filepath

# Get all page titles first
print(f"Fetching page titles from the wiki...")
url = "https://gameofthrones.fandom.com/api.php"
all_page_titles = []
apcontinue = None

while len(all_page_titles) < END_PAGE:
    params = {
        "action": "query",
        "list": "allpages",
        "aplimit": "500",
        "format": "json"
    }
    
    if apcontinue:
        params["apcontinue"] = apcontinue
    
    response = requests.get(url, params=params)
    data = response.json()
    
    pages = [page['title'] for page in data['query']['allpages']]
    all_page_titles.extend(pages)
    
    print(f"  Fetched {len(all_page_titles)} page titles...")
    
    if 'continue' in data and 'apcontinue' in data['continue']:
        apcontinue = data['continue']['apcontinue']
    else:
        break

# Select the page range
pages_to_download = all_page_titles[START_PAGE-1:END_PAGE]
total_pages = len(pages_to_download)

print(f"Downloading pages {START_PAGE} to {END_PAGE} ({total_pages} pages)")


successful = 0
failed = 0
redirects = 0
failed_pages = []

# Prepare fetched pages tracking file inside the output folder
os.makedirs(OUTPUT_FOLDER, exist_ok=True)
# Determine worker-specific filenames
if not WORKER_NAME:
    # Try environment fallbacks if WORKER_NAME not set
    WORKER_NAME = os.getenv('USER') or os.getenv('USERNAME') or 'worker'
safe_worker = WORKER_NAME.replace(' ', '_')
worker_fetched_file = os.path.join(OUTPUT_FOLDER, f"fetched_pages_{safe_worker}.txt")
worker_redirects_file = os.path.join(OUTPUT_FOLDER, f"redirects_{safe_worker}.txt")
worker_failed_file = os.path.join(OUTPUT_FOLDER, f"failed_pages_{safe_worker}.txt")
# Build processed set by reading all workers' fetched files so we avoid re-downloading what others already fetched
processed = set()
for path in glob.glob(os.path.join(OUTPUT_FOLDER, 'fetched_pages_*.txt')):
    try:
        with open(path, 'r', encoding='utf-8') as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    processed.add(int(line))
                except ValueError:
                    pass
    except Exception:
        # ignore unreadable files
        pass

for i, page_title in enumerate(pages_to_download, 1):
    actual_page_num = START_PAGE + i - 1

    # Skip pages that were already processed (downloaded or redirected)
    if actual_page_num in processed:
        print(f"[{actual_page_num}/{END_PAGE}] Skipping (already fetched)")
        continue

    print(f"[{actual_page_num}/{END_PAGE}] Downloading: {page_title}...\n", end=" ")
    
    wikitext = get_page_wikitext(page_title)
    
    if wikitext:
        # Check if this is a redirect page (case-insensitive)
        if wikitext.strip().upper().startswith("#REDIRECT"):
            redirects += 1
            # Log the redirect to a worker-specific file inside the output folder
            with open(worker_redirects_file, "a", encoding="utf-8") as f:
                f.write(f"{page_title} -> {wikitext.strip()}\n")
            # Record the interval number for this redirected page to this worker's fetched file
            with open(worker_fetched_file, "a", encoding="utf-8") as fnum:
                fnum.write(f"{actual_page_num}\n")
            processed.add(actual_page_num)
        else:
            filepath = save_wikitext_to_file(page_title, wikitext, OUTPUT_FOLDER)
            successful += 1
            # Record the interval number for the successfully downloaded page to this worker's file
            with open(worker_fetched_file, "a", encoding="utf-8") as fnum:
                fnum.write(f"{actual_page_num}\n")
            processed.add(actual_page_num)
    else:
        failed += 1
        failed_pages.append(page_title)
        with open(worker_failed_file, "a", encoding="utf-8") as ffail:
            ffail.write(f"{page_title}\n")
        print("✗ Failed")
    
    # Be polite to the server
    time.sleep(0.2)

print(f"\n{'='*60}")
print("DOWNLOAD COMPLETE!")
print(f"{'='*60}")
print(f"Successfully saved: {successful} pages")
print(f"Redirects (skipped): {redirects} pages")
print(f"Failed: {failed} pages")
if failed_pages:
    print(f"\nFailed pages:")
    for page in failed_pages[:10]:
        print(f"  - {page}")
    if len(failed_pages) > 10:
        print(f"  ... and {len(failed_pages) - 10} more")
if redirects > 0:
    print(f"\nRedirects logged to: {worker_redirects_file}")
print(f"\nFiles saved in: {os.path.abspath(OUTPUT_FOLDER)}")
# Out:
# Fetching page titles from the wiki...
#   Fetched 500 page titles...
#   Fetched 500 page titles...
#   Fetched 1000 page titles...
#   Fetched 1000 page titles...
#   Fetched 1500 page titles...
#   Fetched 1500 page titles...
#   Fetched 2000 page titles...
# Downloading pages 1601 to 2000 (400 pages)
# [1601/2000] Downloading: Devan Seaworth...
#    Fetched 2000 page titles...
# Downloading pages 1601 to 2000 (400 pages)
# [1601/2000] Downloading: Devan Seaworth...
#  [1602/2000] Downloading: Devil In Your Eye...
#  [1602/2000] Downloading: Devil In Your Eye...
#  [1603/2000] Downloading: Dexter Sol Ansell...
#  [1603/2000] Downloading: Dexter Sol Ansell...
#  [1604/2000] Downloading: Dez McMahon...
#  [1604/2000] Downloading: Dez McMahon...
#  [1605/2000] Downloading: Deziel Dalt...
#  [1605/2000] Downloading: Deziel Dalt...
#  [1606/2000] Downloading: Diamond Cave...
#  [1606/2000] Downloading: Diamond Cave...
#  [1607/2000] Downloading: Diana Rigg...
#  [1607/2000] Downloading: Diana Rigg...
#  [1608/2000] Downloading: Diana Royce...
#  [1608/2000] Downloading: Diana Royce...
#  [1609/2000] Downloading: Dick Meredith...
#  [1609/2000] Downloading: Dick Meredith...
#  [1610/2000] Downloading: Dickon...
#  [1610/2000] Downloading: Dickon...
#  [1611/2000] Downloading: Dickon Flowers...
#  [1611/2000] Downloading: Dickon Flowers...
#  [1612/2000] Downloading: Dickon Tarly...
#  [1612/2000] Downloading: Dickon Tarly...
#  [1613/2000] Downloading: Diego Herberg...
#  [1613/2000] Downloading: Diego Herberg...
#  [1614/2000] Downloading: Differences in adaptation...
#  [1614/2000] Downloading: Differences in adaptation...
#  [1615/2000] Downloading: Differences in adaptation/Character names, appearances, or ages...
#  [1615/2000] Downloading: Differences in adaptation/Character names, appearances, or ages...
#  [1616/2000] Downloading: Differences in adaptation/Game of Thrones: Season 1...
#  [1616/2000] Downloading: Differences in adaptation/Game of Thrones: Season 1...
#  [1617/2000] Downloading: Differences in adaptation/Game of Thrones: Season 2...
#  [1617/2000] Downloading: Differences in adaptation/Game of Thrones: Season 2...
#  [1618/2000] Downloading: Differences in adaptation/Game of Thrones: Season 3...
#  [1618/2000] Downloading: Differences in adaptation/Game of Thrones: Season 3...
#  [1619/2000] Downloading: Differences in adaptation/Game of Thrones: Season 4...
#  [1619/2000] Downloading: Differences in adaptation/Game of Thrones: Season 4...
#  [1620/2000] Downloading: Differences in adaptation/Game of Thrones: Season 5...
#  [1620/2000] Downloading: Differences in adaptation/Game of Thrones: Season 5...
#  [1621/2000] Downloading: Differences in adaptation/Game of Thrones: Season 6...
#  [1621/2000] Downloading: Differences in adaptation/Game of Thrones: Season 6...
#  [1622/2000] Downloading: Differences in adaptation/Game of Thrones: Season 7...
#  [1622/2000] Downloading: Differences in adaptation/Game of Thrones: Season 7...
#  [1623/2000] Downloading: Differences in adaptation/Game of Thrones: Season 8...
#  [1623/2000] Downloading: Differences in adaptation/Game of Thrones: Season 8...
#  [1624/2000] Downloading: Differences in adaptation/House of the Dragon: Season 1...
#  [1624/2000] Downloading: Differences in adaptation/House of the Dragon: Season 1...
#  [1625/2000] Downloading: Differences in adaptation/House of the Dragon: Season 2...
#  [1625/2000] Downloading: Differences in adaptation/House of the Dragon: Season 2...
#  [1626/2000] Downloading: Differences in adaptation/New characters...
#  [1626/2000] Downloading: Differences in adaptation/New characters...
#  [1627/2000] Downloading: Differences in adaptation/Significantly changed characters...
#  [1627/2000] Downloading: Differences in adaptation/Significantly changed characters...
#  [1628/2000] Downloading: Differences in adaptation/Status of women...
#  [1628/2000] Downloading: Differences in adaptation/Status of women...
#  [1629/2000] Downloading: Dim Dalba...
#  [1629/2000] Downloading: Dim Dalba...
#  [1630/2000] Downloading: Dimitar Doychinov...
#  [1630/2000] Downloading: Dimitar Doychinov...
#  [1631/2000] Downloading: Diogo Sales...
#  [1631/2000] Downloading: Diogo Sales...
#  [1632/2000] Downloading: Dirah...
#  [1632/2000] Downloading: Dirah...
#  [1633/2000] Downloading: Dire Den...
#  [1633/2000] Downloading: Dire Den...
#  [1634/2000] Downloading: Direwolf...
#  [1634/2000] Downloading: Direwolf...
#  [1635/2000] Downloading: Dirk...
#  [1635/2000] Downloading: Dirk...
#  [1636/2000] Downloading: Disputed Lands...
#  [1636/2000] Downloading: Disputed Lands...
#  [1637/2000] Downloading: Dixie Egerickx...
#  [1637/2000] Downloading: Dixie Egerickx...
#  [1638/2000] Downloading: Dog...
#  [1638/2000] Downloading: Dog...
#  [1639/2000] Downloading: Dolf...
#  [1639/2000] Downloading: Dolf...
#  [1640/2000] Downloading: Dolf son of Holger...
#  [1640/2000] Downloading: Dolf son of Holger...
#  [1641/2000] Downloading: Dolorous Edd...
#  [1641/2000] Downloading: Dolorous Edd...
#  [1642/2000] Downloading: Dom...
#  [1642/2000] Downloading: Dom...
#  [1643/2000] Downloading: Dom Dumaresq...
#  [1643/2000] Downloading: Dom Dumaresq...
#  [1644/2000] Downloading: Domagoj Ljubicic...
#  [1644/2000] Downloading: Domagoj Ljubicic...
#  [1645/2000] Downloading: Domeric Bolton...
#  [1645/2000] Downloading: Domeric Bolton...
#  [1646/2000] Downloading: Dominic Carter...
#  [1646/2000] Downloading: Dominic Carter...
#  [1647/2000] Downloading: Dominic Preece...
#  [1647/2000] Downloading: Dominic Preece...
#  [1648/2000] Downloading: Domonkos Pardanyi...
#  [1648/2000] Downloading: Domonkos Pardanyi...
#  [1649/2000] Downloading: Don't Die With A Clean Sword...
#  [1649/2000] Downloading: Don't Die With A Clean Sword...
#  [1650/2000] Downloading: Donagh Deeney...
#  [1650/2000] Downloading: Donagh Deeney...
#  [1651/2000] Downloading: Donal Gallery...
#  [1651/2000] Downloading: Donal Gallery...
#  [1652/2000] Downloading: Donal Royce...
#  [1652/2000] Downloading: Donal Royce...
#  [1653/2000] Downloading: Donal Royce (son of Donal)...
#  [1653/2000] Downloading: Donal Royce (son of Donal)...
#  [1654/2000] Downloading: Donald Sumpter...
#  [1654/2000] Downloading: Donald Sumpter...
#  [1655/2000] Downloading: Dondarrion...
#  [1655/2000] Downloading: Dondarrion...
#  [1656/2000] Downloading: Dongo...
#  [1656/2000] Downloading: Dongo...
#  [1657/2000] Downloading: Dongo the Doomed...
#  [1657/2000] Downloading: Dongo the Doomed...
#  [1658/2000] Downloading: Donna Williams...
#  [1658/2000] Downloading: Donna Williams...
#  [1659/2000] Downloading: Donnel Hill...
#  [1659/2000] Downloading: Donnel Hill...
#  [1660/2000] Downloading: Donnel Waynwood...
#  [1660/2000] Downloading: Donnel Waynwood...
#  [1661/2000] Downloading: Donnel of Duskendale...
#  [1661/2000] Downloading: Donnel of Duskendale...
#  [1662/2000] Downloading: Dontos...
#  [1662/2000] Downloading: Dontos...
#  [1663/2000] Downloading: Dontos Hollard...
#  [1663/2000] Downloading: Dontos Hollard...
#  [1664/2000] Downloading: Dontos the Red...
#  [1664/2000] Downloading: Dontos the Red...
#  [1665/2000] Downloading: Doom...
#  [1665/2000] Downloading: Doom...
#  [1666/2000] Downloading: Doom of Valyria...
#  [1666/2000] Downloading: Doom of Valyria...
#  [1667/2000] Downloading: Doom of Valyria (pitch)...
#  [1667/2000] Downloading: Doom of Valyria (pitch)...
#  [1668/2000] Downloading: Doom of the Valyrian Freehold...
#  [1668/2000] Downloading: Doom of the Valyrian Freehold...
#  [1669/2000] Downloading: Doran Martell...
#  [1669/2000] Downloading: Doran Martell...
#  [1670/2000] Downloading: Dorea Sand...
#  [1670/2000] Downloading: Dorea Sand...
#  [1671/2000] Downloading: Doreah...
#  [1671/2000] Downloading: Doreah...
#  [1672/2000] Downloading: Doren Farmer...
#  [1672/2000] Downloading: Doren Farmer...
#  [1673/2000] Downloading: Doren John Farmer...
#  [1673/2000] Downloading: Doren John Farmer...
#  [1674/2000] Downloading: Dorgas Hunter...
#  [1674/2000] Downloading: Dorgas Hunter...
#  [1675/2000] Downloading: Dorian Hightower...
#  [1675/2000] Downloading: Dorian Hightower...
#  [1676/2000] Downloading: Dorian Hightower's first wife...
#  [1676/2000] Downloading: Dorian Hightower's first wife...
#  [1677/2000] Downloading: Dorian Hightower's second wife...
#  [1677/2000] Downloading: Dorian Hightower's second wife...
#  [1678/2000] Downloading: Dormand Hall...
#  [1678/2000] Downloading: Dormand Hall...
#  [1679/2000] Downloading: Dorna...
#  [1679/2000] Downloading: Dorna...
#  [1680/2000] Downloading: Dorna Lannister...
#  [1680/2000] Downloading: Dorna Lannister...
#  [1681/2000] Downloading: Dorna Swyft...
#  [1681/2000] Downloading: Dorna Swyft...
#  [1682/2000] Downloading: Dorne...
#  [1682/2000] Downloading: Dorne...
#  [1683/2000] Downloading: Dorne (short)...
#  [1683/2000] Downloading: Dorne (short)...
#  [1684/2000] Downloading: Dornish...
#  [1684/2000] Downloading: Dornish...
#  [1685/2000] Downloading: Dornish Marches...
#  [1685/2000] Downloading: Dornish Marches...
#  [1686/2000] Downloading: Dornish sack of Highgarden...
#  [1686/2000] Downloading: Dornish sack of Highgarden...
#  [1687/2000] Downloading: Dornishmen...
#  [1687/2000] Downloading: Dornishmen...
#  [1688/2000] Downloading: Dorren Stark...
#  [1688/2000] Downloading: Dorren Stark...
#  [1689/2000] Downloading: Dosh Khaleen...
#  [1689/2000] Downloading: Dosh Khaleen...
#  [1690/2000] Downloading: Dosk...
#  [1690/2000] Downloading: Dosk...
#  [1691/2000] Downloading: Dothraki...
#  [1691/2000] Downloading: Dothraki...
#  [1692/2000] Downloading: Dothraki (disambiguation)...
#  [1692/2000] Downloading: Dothraki (disambiguation)...
#  [1693/2000] Downloading: Dothraki (language)...
#  [1693/2000] Downloading: Dothraki (language)...
#  [1694/2000] Downloading: Dothraki Sea...
#  [1694/2000] Downloading: Dothraki Sea...
#  [1695/2000] Downloading: Dothraki crone...
#  [1695/2000] Downloading: Dothraki crone...
#  [1696/2000] Downloading: Dothraki religion...
#  [1696/2000] Downloading: Dothraki religion...
#  [1697/2000] Downloading: Dothraki sea...
#  [1697/2000] Downloading: Dothraki sea...
#  [1698/2000] Downloading: Doug Robson...
#  [1698/2000] Downloading: Doug Robson...
#  [1699/2000] Downloading: Doug Seus...
#  [1699/2000] Downloading: Doug Seus...
#  [1700/2000] Downloading: Doug Wheatley...
#  [1700/2000] Downloading: Doug Wheatley...
#  [1701/2000] Downloading: Dougie Wighton...
#  [1701/2000] Downloading: Dougie Wighton...
#  [1702/2000] Downloading: Douglas Robson...
#  [1702/2000] Downloading: Douglas Robson...
#  [1703/2000] Downloading: Douglas Wells...
#  [1703/2000] Downloading: Douglas Wells...
#  [1704/2000] Downloading: Douglas Wighton...
#  [1704/2000] Downloading: Douglas Wighton...
#  [1705/2000] Downloading: Doyin Ajiboye...
#  [1705/2000] Downloading: Doyin Ajiboye...
#  [1706/2000] Downloading: Dracarys...
#  [1706/2000] Downloading: Dracarys...
#  [1707/2000] Downloading: Dracarys (track)...
#  [1707/2000] Downloading: Dracarys (track)...
#  [1708/2000] Downloading: Dragon...
#  [1708/2000] Downloading: Dragon...
#  [1709/2000] Downloading: Dragon's Wroth...
#  [1709/2000] Downloading: Dragon's Wroth...
#  [1710/2000] Downloading: Dragon Deep Dive with Sound Designer Paula Fairfield...
#  [1710/2000] Downloading: Dragon Deep Dive with Sound Designer Paula Fairfield...
#  [1711/2000] Downloading: Dragon dream...
#  [1711/2000] Downloading: Dragon dream...
#  [1712/2000] Downloading: Dragon dreams...
#  [1712/2000] Downloading: Dragon dreams...
#  [1713/2000] Downloading: Dragon roads...
#  [1713/2000] Downloading: Dragon roads...
#  [1714/2000] Downloading: Dragonbone...
#  [1714/2000] Downloading: Dragonbone...
#  [1715/2000] Downloading: Dragonglass...
#  [1715/2000] Downloading: Dragonglass...
#  [1716/2000] Downloading: Dragonglass (book)...
#  [1716/2000] Downloading: Dragonglass (book)...
#  [1717/2000] Downloading: Dragonglass (track)...
#  [1717/2000] Downloading: Dragonglass (track)...
#  [1718/2000] Downloading: Dragonglass candle...
#  [1718/2000] Downloading: Dragonglass candle...
#  [1719/2000] Downloading: Dragonkeeper Acolyte (The Heirs of the Dragon)...
#  [1719/2000] Downloading: Dragonkeeper Acolyte (The Heirs of the Dragon)...
#  [1720/2000] Downloading: Dragonkeeper Elder (The Heirs of the Dragon)...
#  [1720/2000] Downloading: Dragonkeeper Elder (The Heirs of the Dragon)...
#  [1721/2000] Downloading: Dragonkeeper Elder (The Princess and the Queen)...
#  [1721/2000] Downloading: Dragonkeeper Elder (The Princess and the Queen)...
#  [1722/2000] Downloading: Dragonkeepers...
#  [1722/2000] Downloading: Dragonkeepers...
#      Error: ('Connection aborted.', ConnectionResetError(10054, 'En eksisterende forbindelse blev tvangsafbrudt af en ekstern vært', None, 10054, None))
# ✗ Failed
# [1723/2000] Downloading: Dragonknight...
#      Error: ('Connection aborted.', ConnectionResetError(10054, 'En eksisterende forbindelse blev tvangsafbrudt af en ekstern vært', None, 10054, None))
# ✗ Failed
# [1723/2000] Downloading: Dragonknight...
#  [1724/2000] Downloading: Dragonlord...
#  [1724/2000] Downloading: Dragonlord...
#  [1725/2000] Downloading: Dragonlords...
#  [1725/2000] Downloading: Dragonlords...
#  [1726/2000] Downloading: Dragonmont...
#  [1726/2000] Downloading: Dragonmont...
#  [1727/2000] Downloading: Dragonmother...
#  [1727/2000] Downloading: Dragonmother...
#  [1728/2000] Downloading: Dragonmount...
#  [1728/2000] Downloading: Dragonmount...
#  [1729/2000] Downloading: Dragonpit...
#  [1729/2000] Downloading: Dragonpit...
#  [1730/2000] Downloading: Dragonpit Summit...
#  [1730/2000] Downloading: Dragonpit Summit...
#  [1731/2000] Downloading: Dragonrider...
#  [1731/2000] Downloading: Dragonrider...
#  [1732/2000] Downloading: Dragons...
#  [1732/2000] Downloading: Dragons...
#  [1733/2000] Downloading: Dragons (book)...
#  [1733/2000] Downloading: Dragons (book)...
#  [1734/2000] Downloading: Dragons (disambiguation)...
#  [1734/2000] Downloading: Dragons (disambiguation)...
#  [1735/2000] Downloading: Dragons (short)...
#  [1735/2000] Downloading: Dragons (short)...
#  [1736/2000] Downloading: Dragons Do Not Fear Blood...
#  [1736/2000] Downloading: Dragons Do Not Fear Blood...
#  [1737/2000] Downloading: Dragons Will Rule the Kingdom...
#  [1737/2000] Downloading: Dragons Will Rule the Kingdom...
#  [1738/2000] Downloading: Dragonseed...
#  [1738/2000] Downloading: Dragonseed...
#  [1739/2000] Downloading: Dragonseeds...
#  [1739/2000] Downloading: Dragonseeds...
#  [1740/2000] Downloading: Dragonsong...
#  [1740/2000] Downloading: Dragonsong...
#  [1741/2000] Downloading: Dragonsteel...
#  [1741/2000] Downloading: Dragonsteel...
#  [1742/2000] Downloading: Dragonstone...
#  [1742/2000] Downloading: Dragonstone...
#  [1743/2000] Downloading: Dragonstone (Game of Thrones: Inside the Episode)...
#  [1743/2000] Downloading: Dragonstone (Game of Thrones: Inside the Episode)...
#  [1744/2000] Downloading: Dragonstone (Histories & Lore)...
#  [1744/2000] Downloading: Dragonstone (Histories & Lore)...
#  [1745/2000] Downloading: Dragonstone (disambiguation)...
#  [1745/2000] Downloading: Dragonstone (disambiguation)...
#  [1746/2000] Downloading: Dragonstone (episode)...
#  [1746/2000] Downloading: Dragonstone (episode)...
#  [1747/2000] Downloading: Dragonstone (episode)/Appearances...
#  [1747/2000] Downloading: Dragonstone (episode)/Appearances...
#  [1748/2000] Downloading: Dragonstone (island)...
#  [1748/2000] Downloading: Dragonstone (island)...
#  [1749/2000] Downloading: Dragonstone (material)...
#  [1749/2000] Downloading: Dragonstone (material)...
#  [1750/2000] Downloading: Dragonstone (track)...
#  [1750/2000] Downloading: Dragonstone (track)...
#  [1751/2000] Downloading: Dragonstone Castle...
#  [1751/2000] Downloading: Dragonstone Castle...
#  [1752/2000] Downloading: Dragonstone island...
#  [1752/2000] Downloading: Dragonstone island...
#  [1753/2000] Downloading: Dreadfort...
#  [1753/2000] Downloading: Dreadfort...
#  [1754/2000] Downloading: Dreamer...
#  [1754/2000] Downloading: Dreamer...
#  [1755/2000] Downloading: Dreamers...
#  [1755/2000] Downloading: Dreamers...
#  [1756/2000] Downloading: Dreamfyre...
#  [1756/2000] Downloading: Dreamfyre...
#  [1757/2000] Downloading: Dreams...
#  [1757/2000] Downloading: Dreams...
#  [1758/2000] Downloading: Dreams and prophecies...
#  [1758/2000] Downloading: Dreams and prophecies...
#  [1759/2000] Downloading: Drennan...
#  [1759/2000] Downloading: Drennan...
#  [1760/2000] Downloading: Driftmark...
#  [1760/2000] Downloading: Driftmark...
#  [1761/2000] Downloading: Driftmark (disambiguation)...
#  [1761/2000] Downloading: Driftmark (disambiguation)...
#  [1762/2000] Downloading: Driftmark (episode)...
#  [1762/2000] Downloading: Driftmark (episode)...
#  [1763/2000] Downloading: Driftmark (episode)/Appearances...
#  [1763/2000] Downloading: Driftmark (episode)/Appearances...
#  [1764/2000] Downloading: Driftmark (short)...
#  [1764/2000] Downloading: Driftmark (short)...
#  [1765/2000] Downloading: Driftwood Throne...
#  [1765/2000] Downloading: Driftwood Throne...
#  [1766/2000] Downloading: Dritan Kastrati...
#  [1766/2000] Downloading: Dritan Kastrati...
#  [1767/2000] Downloading: Drogo...
#  [1767/2000] Downloading: Drogo...
#  [1768/2000] Downloading: Drogo's stallion...
#  [1768/2000] Downloading: Drogo's stallion...
#  [1769/2000] Downloading: Drogon...
#  [1769/2000] Downloading: Drogon...
#  [1770/2000] Downloading: Drowned God...
#  [1770/2000] Downloading: Drowned God...
#  [1771/2000] Downloading: Drowned Man...
#  [1771/2000] Downloading: Drowned Man...
#  [1772/2000] Downloading: Drowned Men...
#  [1772/2000] Downloading: Drowned Men...
#  [1773/2000] Downloading: Duel on Dragonstone...
#  [1773/2000] Downloading: Duel on Dragonstone...
#  [1774/2000] Downloading: Dun Fort...
#  [1774/2000] Downloading: Dun Fort...
#  [1775/2000] Downloading: Duncan...
#  [1775/2000] Downloading: Duncan...
#  [1776/2000] Downloading: Duncan Lacroix...
#  [1776/2000] Downloading: Duncan Lacroix...
#  [1777/2000] Downloading: Duncan Liddle...
#  [1777/2000] Downloading: Duncan Liddle...
#  [1778/2000] Downloading: Duncan Muggoch...
#  [1778/2000] Downloading: Duncan Muggoch...
#  [1779/2000] Downloading: Duncan Targaryen...
#  [1779/2000] Downloading: Duncan Targaryen...
#  [1780/2000] Downloading: Duncan the Tall...
#  [1780/2000] Downloading: Duncan the Tall...
#  [1781/2000] Downloading: Dunk...
#  [1781/2000] Downloading: Dunk...
#  [1782/2000] Downloading: Dunk & Egg...
#  [1782/2000] Downloading: Dunk & Egg...
#  [1783/2000] Downloading: Dunk & Egg novellas...
#  [1783/2000] Downloading: Dunk & Egg novellas...
#  [1784/2000] Downloading: Dunk and Egg...
#  [1784/2000] Downloading: Dunk and Egg...
#  [1785/2000] Downloading: Dunstonbury...
#  [1785/2000] Downloading: Dunstonbury...
#  [1786/2000] Downloading: Durran...
#  [1786/2000] Downloading: Durran...
#  [1787/2000] Downloading: Durran's Point...
#  [1787/2000] Downloading: Durran's Point...
#  [1788/2000] Downloading: Durran Godsgrief...
#  [1788/2000] Downloading: Durran Godsgrief...
#  [1789/2000] Downloading: Dusk rose...
#  [1789/2000] Downloading: Dusk rose...
#  [1790/2000] Downloading: Duskendale...
#  [1790/2000] Downloading: Duskendale...
#  [1791/2000] Downloading: Dwarf...
#  [1791/2000] Downloading: Dwarf...
#  [1792/2000] Downloading: Dwarf 1...
#  [1792/2000] Downloading: Dwarf 1...
#  [1793/2000] Downloading: Dwarf 2...
#  [1793/2000] Downloading: Dwarf 2...
#  [1794/2000] Downloading: Dwarf 3...
#  [1794/2000] Downloading: Dwarf 3...
#  [1795/2000] Downloading: Dwarf 4...
#  [1795/2000] Downloading: Dwarf 4...
#  [1796/2000] Downloading: Dwarf 5...
#  [1796/2000] Downloading: Dwarf 5...
#  [1797/2000] Downloading: Dwarf elephant...
#  [1797/2000] Downloading: Dwarf elephant...
#  [1798/2000] Downloading: Dwarfs...
#  [1798/2000] Downloading: Dwarfs...
#  [1799/2000] Downloading: Dwarfstone...
#  [1799/2000] Downloading: Dwarfstone...
#  [1800/2000] Downloading: Dwarves...
#  [1800/2000] Downloading: Dwarves...
#  [1801/2000] Downloading: Dyana...
#  [1801/2000] Downloading: Dyana...
#  [1802/2000] Downloading: Dyanna Dayne...
#  [1802/2000] Downloading: Dyanna Dayne...
#  [1803/2000] Downloading: Dying man...
#  [1803/2000] Downloading: Dying man...
#  [1804/2000] Downloading: Dying of the Dragons...
#  [1804/2000] Downloading: Dying of the Dragons...
#  [1805/2000] Downloading: Dylan Edwards...
#  [1805/2000] Downloading: Dylan Edwards...
#  [1806/2000] Downloading: Dylan Jones...
#  [1806/2000] Downloading: Dylan Jones...
#  [1807/2000] Downloading: Dylan McDonough...
#  [1807/2000] Downloading: Dylan McDonough...
#  [1808/2000] Downloading: Dyre Den...
#  [1808/2000] Downloading: Dyre Den...
#  [1809/2000] Downloading: EG:ALAF...
#  [1809/2000] Downloading: EG:ALAF...
#  [1810/2000] Downloading: EG:BOX...
#  [1810/2000] Downloading: EG:BOX...
#  [1811/2000] Downloading: EG:BOXINPUT...
#  [1811/2000] Downloading: EG:BOXINPUT...
#  [1812/2000] Downloading: EG:CASTFORM...
#  [1812/2000] Downloading: EG:CASTFORM...
#  [1813/2000] Downloading: EG:CHARFORM...
#  [1813/2000] Downloading: EG:CHARFORM...
#  [1814/2000] Downloading: EG:DATES...
#  [1814/2000] Downloading: EG:DATES...
#  [1815/2000] Downloading: EG:EDIT...
#  [1815/2000] Downloading: EG:EDIT...
#  [1816/2000] Downloading: EG:EDITING...
#  [1816/2000] Downloading: EG:EDITING...
#  [1817/2000] Downloading: EG:ENTONE...
#  [1817/2000] Downloading: EG:ENTONE...
#  [1818/2000] Downloading: EG:EPFORM...
#  [1818/2000] Downloading: EG:EPFORM...
#  [1819/2000] Downloading: EG:FORMATTING...
#  [1819/2000] Downloading: EG:FORMATTING...
#  [1820/2000] Downloading: EG:GENEDIT...
#  [1820/2000] Downloading: EG:GENEDIT...
#  [1821/2000] Downloading: EG:GENFORM...
#  [1821/2000] Downloading: EG:GENFORM...
#  [1822/2000] Downloading: EG:GENINFO...
#  [1822/2000] Downloading: EG:GENINFO...
#  [1823/2000] Downloading: EG:GENTEM...
#  [1823/2000] Downloading: EG:GENTEM...
#  [1824/2000] Downloading: EG:GENTEMP...
#  [1824/2000] Downloading: EG:GENTEMP...
#  [1825/2000] Downloading: EG:GENWRITE...
#  [1825/2000] Downloading: EG:GENWRITE...
#  [1826/2000] Downloading: EG:GFP...
#  [1826/2000] Downloading: EG:GFP...
#  [1827/2000] Downloading: EG:GIP...
#  [1827/2000] Downloading: EG:GIP...
#  [1828/2000] Downloading: EG:GTP...
#  [1828/2000] Downloading: EG:GTP...
#  [1829/2000] Downloading: EG:GWP...
#  [1829/2000] Downloading: EG:GWP...
#  [1830/2000] Downloading: EG:HERALDRY...
#  [1830/2000] Downloading: EG:HERALDRY...
#  [1831/2000] Downloading: EG:IB...
#  [1831/2000] Downloading: EG:IB...
#  [1832/2000] Downloading: EG:INFOBOX...
#  [1832/2000] Downloading: EG:INFOBOX...
#  [1833/2000] Downloading: EG:INFOCHAR...
#  [1833/2000] Downloading: EG:INFOCHAR...
#  [1834/2000] Downloading: EG:LINKING...
#  [1834/2000] Downloading: EG:LINKING...
#  [1835/2000] Downloading: EG:LINKS...
#  [1835/2000] Downloading: EG:LINKS...
#  [1836/2000] Downloading: EG:NPOV...
#  [1836/2000] Downloading: EG:NPOV...
#  [1837/2000] Downloading: EG:QUOTES...
#  [1837/2000] Downloading: EG:QUOTES...
#  [1838/2000] Downloading: EG:REF...
#  [1838/2000] Downloading: EG:REF...
#  [1839/2000] Downloading: EG:REFERENCES...
#  [1839/2000] Downloading: EG:REFERENCES...
#  [1840/2000] Downloading: EG:SIGNATURES...
#  [1840/2000] Downloading: EG:SIGNATURES...
#  [1841/2000] Downloading: EG:TALK...
#  [1841/2000] Downloading: EG:TALK...
#  [1842/2000] Downloading: EG:TEM...
#  [1842/2000] Downloading: EG:TEM...
#  [1843/2000] Downloading: EG:TEMP...
#  [1843/2000] Downloading: EG:TEMP...
#  [1844/2000] Downloading: EG:TEMPLATE...
#  [1844/2000] Downloading: EG:TEMPLATE...
#  [1845/2000] Downloading: EG:TITLES...
#  [1845/2000] Downloading: EG:TITLES...
#  [1846/2000] Downloading: EG:USERPAGE...
#  [1846/2000] Downloading: EG:USERPAGE...
#  [1847/2000] Downloading: EG:WGS...
#  [1847/2000] Downloading: EG:WGS...
#  [1848/2000] Downloading: EG:WRITING...
#  [1848/2000] Downloading: EG:WRITING...
#  [1849/2000] Downloading: Eamon Keenan...
#  [1849/2000] Downloading: Eamon Keenan...
#  [1850/2000] Downloading: Eamonn Draper...
#  [1850/2000] Downloading: Eamonn Draper...
#  [1851/2000] Downloading: East...
#  [1851/2000] Downloading: East...
#  [1852/2000] Downloading: Eastern Road...
#  [1852/2000] Downloading: Eastern Road...
#  [1853/2000] Downloading: Eastern continent...
#  [1853/2000] Downloading: Eastern continent...
#  [1854/2000] Downloading: Eastern road...
#  [1854/2000] Downloading: Eastern road...
#  [1855/2000] Downloading: Eastwatch...
#  [1855/2000] Downloading: Eastwatch...
#  [1856/2000] Downloading: Eastwatch-by-the-Sea...
#  [1856/2000] Downloading: Eastwatch-by-the-Sea...
#  [1857/2000] Downloading: Eastwatch/Appearances...
#  [1857/2000] Downloading: Eastwatch/Appearances...
#  [1858/2000] Downloading: Eastwatch (disambiguation)...
#  [1858/2000] Downloading: Eastwatch (disambiguation)...
#  [1859/2000] Downloading: Eastwatch (short)...
#  [1859/2000] Downloading: Eastwatch (short)...
#  [1860/2000] Downloading: Eboni Booth...
#  [1860/2000] Downloading: Eboni Booth...
#  [1861/2000] Downloading: Ebrose...
#  [1861/2000] Downloading: Ebrose...
#  [1862/2000] Downloading: Echeal...
#  [1862/2000] Downloading: Echeal...
#  [1863/2000] Downloading: Echiel...
#  [1863/2000] Downloading: Echiel...
#  [1864/2000] Downloading: Ector Swann...
#  [1864/2000] Downloading: Ector Swann...
#  [1865/2000] Downloading: Ed Sheeran...
#  [1865/2000] Downloading: Ed Sheeran...
#  [1866/2000] Downloading: Ed Skrein...
#  [1866/2000] Downloading: Ed Skrein...
#  [1867/2000] Downloading: Edd Tollett...
#  [1867/2000] Downloading: Edd Tollett...
#  [1868/2000] Downloading: Eddard...
#  [1868/2000] Downloading: Eddard...
#  [1869/2000] Downloading: Eddard (disambiguation)...
#  [1869/2000] Downloading: Eddard (disambiguation)...
#  [1870/2000] Downloading: Eddard Stark...
#  [1870/2000] Downloading: Eddard Stark...
#  [1871/2000] Downloading: Eddard Waters...
#  [1871/2000] Downloading: Eddard Waters...
#  [1872/2000] Downloading: Eddie...
#  [1872/2000] Downloading: Eddie...
#  [1873/2000] Downloading: Eddie Elks...
#  [1873/2000] Downloading: Eddie Elks...
#  [1874/2000] Downloading: Eddie Eyre...
#  [1874/2000] Downloading: Eddie Eyre...
#  [1875/2000] Downloading: Eddie Jackson...
#  [1875/2000] Downloading: Eddie Jackson...
#  [1876/2000] Downloading: Eddison Tollett...
#  [1876/2000] Downloading: Eddison Tollett...
#  [1877/2000] Downloading: Eddy Beckett...
#  [1877/2000] Downloading: Eddy Beckett...
#  [1878/2000] Downloading: Edgar Yronwood...
#  [1878/2000] Downloading: Edgar Yronwood...
#  [1879/2000] Downloading: Editing guidelines...
#  [1879/2000] Downloading: Editing guidelines...
#  [1880/2000] Downloading: Editing policy...
#  [1880/2000] Downloading: Editing policy...
#  [1881/2000] Downloading: Edmure...
#  [1881/2000] Downloading: Edmure...
#  [1882/2000] Downloading: Edmure Tully...
#  [1882/2000] Downloading: Edmure Tully...
#  [1883/2000] Downloading: Edmure Tully's son...
#  [1883/2000] Downloading: Edmure Tully's son...
#  [1884/2000] Downloading: Edmyn Tully...
#  [1884/2000] Downloading: Edmyn Tully...
#  [1885/2000] Downloading: Edric Baratheon...
#  [1885/2000] Downloading: Edric Baratheon...
#  [1886/2000] Downloading: Eduard Hendija...
#  [1886/2000] Downloading: Eduard Hendija...
#  [1887/2000] Downloading: Eduardo Gago...
#  [1887/2000] Downloading: Eduardo Gago...
#  [1888/2000] Downloading: Eduardo Gago Muñoz...
#  [1888/2000] Downloading: Eduardo Gago Muñoz...
#  [1889/2000] Downloading: Eduardo Moratilla...
#  [1889/2000] Downloading: Eduardo Moratilla...
#  [1890/2000] Downloading: Edward Ashley...
#  [1890/2000] Downloading: Edward Ashley...
#  [1891/2000] Downloading: Edward Dogliani...
#  [1891/2000] Downloading: Edward Dogliani...
#  [1892/2000] Downloading: Edward Mercieca...
#  [1892/2000] Downloading: Edward Mercieca...
#  [1893/2000] Downloading: Edward Rowe...
#  [1893/2000] Downloading: Edward Rowe...
#  [1894/2000] Downloading: Edward Tudor-Pole...
#  [1894/2000] Downloading: Edward Tudor-Pole...
#  [1895/2000] Downloading: Edward Tudor Pole...
#  [1895/2000] Downloading: Edward Tudor Pole...
#  [1896/2000] Downloading: Edward Upcott...
#  [1896/2000] Downloading: Edward Upcott...
#  [1897/2000] Downloading: Edwell Celtigar...
#  [1897/2000] Downloading: Edwell Celtigar...
#  [1898/2000] Downloading: Edwina Royce...
#  [1898/2000] Downloading: Edwina Royce...
#  [1899/2000] Downloading: Egg...
#  [1899/2000] Downloading: Egg...
#  [1900/2000] Downloading: Eglantine...
#  [1900/2000] Downloading: Eglantine...
#  [1901/2000] Downloading: Eileen McCloskey...
#  [1901/2000] Downloading: Eileen McCloskey...
#  [1902/2000] Downloading: Eileen Shim...
#  [1902/2000] Downloading: Eileen Shim...
#  [1903/2000] Downloading: Eivør Pálsdóttir...
#  [1903/2000] Downloading: Eivør Pálsdóttir...
#  [1904/2000] Downloading: Ekene Ikedife...
#  [1904/2000] Downloading: Ekene Ikedife...
#  [1905/2000] Downloading: El Hasani...
#  [1905/2000] Downloading: El Hasani...
#  [1906/2000] Downloading: Elaena Targaryen...
#  [1906/2000] Downloading: Elaena Targaryen...
#  [1907/2000] Downloading: Elaena Targaryen (wife of Aenar)...
#  [1907/2000] Downloading: Elaena Targaryen (wife of Aenar)...
#  [1908/2000] Downloading: Elbert Arryn...
#  [1908/2000] Downloading: Elbert Arryn...
#  [1909/2000] Downloading: Elder Brother...
#  [1909/2000] Downloading: Elder Brother...
#  [1910/2000] Downloading: Elder slave...
#  [1910/2000] Downloading: Elder slave...
#  [1911/2000] Downloading: Elders of Qarth...
#  [1911/2000] Downloading: Elders of Qarth...
#  [1912/2000] Downloading: Eldredd Wolf...
#  [1912/2000] Downloading: Eldredd Wolf...
#  [1913/2000] Downloading: Eldric Shadowchaser...
#  [1913/2000] Downloading: Eldric Shadowchaser...
#  [1914/2000] Downloading: Eldrick Sarsfield...
#  [1914/2000] Downloading: Eldrick Sarsfield...
#  [1915/2000] Downloading: Eleanor Swann...
#  [1915/2000] Downloading: Eleanor Swann...
#  [1916/2000] Downloading: Election of the 998th Lord Commander...
#  [1916/2000] Downloading: Election of the 998th Lord Commander...
#  [1917/2000] Downloading: Elections...
#  [1917/2000] Downloading: Elections...
#  [1918/2000] Downloading: Eledro Wolf...
#  [1918/2000] Downloading: Eledro Wolf...
#  [1919/2000] Downloading: Elena Egen...
#  [1919/2000] Downloading: Elena Egen...
#  [1920/2000] Downloading: Elenei...
#  [1920/2000] Downloading: Elenei...
#  [1921/2000] Downloading: Elephant...
#  [1921/2000] Downloading: Elephant...
#  [1922/2000] Downloading: Elia Martell...
#  [1922/2000] Downloading: Elia Martell...
#  [1923/2000] Downloading: Elia Mervi...
#  [1923/2000] Downloading: Elia Mervi...
#  [1924/2000] Downloading: Elia Sand...
#  [1924/2000] Downloading: Elia Sand...
#  [1925/2000] Downloading: Elia Targaryen...
#  [1925/2000] Downloading: Elia Targaryen...
#  [1926/2000] Downloading: Elie Haddad...
#  [1926/2000] Downloading: Elie Haddad...
#  [1927/2000] Downloading: Elinda Massey...
#  [1927/2000] Downloading: Elinda Massey...
#  [1928/2000] Downloading: Eline Powell...
#  [1928/2000] Downloading: Eline Powell...
#  [1929/2000] Downloading: Elinor...
#  [1929/2000] Downloading: Elinor...
#  [1930/2000] Downloading: Elinor Costayne...
#  [1930/2000] Downloading: Elinor Costayne...
#  [1931/2000] Downloading: Elinor Stokeworth...
#  [1931/2000] Downloading: Elinor Stokeworth...
#  [1932/2000] Downloading: Elisa Lasowski...
#  [1932/2000] Downloading: Elisa Lasowski...
#  [1933/2000] Downloading: Elitsa Razheva...
#  [1933/2000] Downloading: Elitsa Razheva...
#  [1934/2000] Downloading: Elizabeth Barrett...
#  [1934/2000] Downloading: Elizabeth Barrett...
#  [1935/2000] Downloading: Elizabeth Cadwallader...
#  [1935/2000] Downloading: Elizabeth Cadwallader...
#  [1936/2000] Downloading: Elizabeth Donker Curtis...
#  [1936/2000] Downloading: Elizabeth Donker Curtis...
#  [1937/2000] Downloading: Elizabeth Webster...
#  [1937/2000] Downloading: Elizabeth Webster...
#  [1938/2000] Downloading: Ella-Rose Sands...
#  [1938/2000] Downloading: Ella-Rose Sands...
#  [1939/2000] Downloading: Ella Hughes...
#  [1939/2000] Downloading: Ella Hughes...
#  [1940/2000] Downloading: Ella Tweed...
#  [1940/2000] Downloading: Ella Tweed...
#  [1941/2000] Downloading: Ellaria Sand...
#  [1941/2000] Downloading: Ellaria Sand...
#  [1942/2000] Downloading: Ellie Kendrick...
#  [1942/2000] Downloading: Ellie Kendrick...
#  [1943/2000] Downloading: Elliot Grihault...
#  [1943/2000] Downloading: Elliot Grihault...
#  [1944/2000] Downloading: Elliot Murray...
#  [1944/2000] Downloading: Elliot Murray...
#  [1945/2000] Downloading: Elliott Murray...
#  [1945/2000] Downloading: Elliott Murray...
#  [1946/2000] Downloading: Elliott Tittensor...
#  [1946/2000] Downloading: Elliott Tittensor...
#  [1947/2000] Downloading: Ellora Torchia...
#  [1947/2000] Downloading: Ellora Torchia...
#  [1948/2000] Downloading: Ellyn Baratheon...
#  [1948/2000] Downloading: Ellyn Baratheon...
#  [1949/2000] Downloading: Ellyn Reyne...
#  [1949/2000] Downloading: Ellyn Reyne...
#  [1950/2000] Downloading: Ellyn Tarbeck...
#  [1950/2000] Downloading: Ellyn Tarbeck...
#  [1951/2000] Downloading: Elmo Tully...
#  [1951/2000] Downloading: Elmo Tully...
#  [1952/2000] Downloading: Elmo Walker...
#  [1952/2000] Downloading: Elmo Walker...
#  [1953/2000] Downloading: Elyes Gabel...
#  [1953/2000] Downloading: Elyes Gabel...
#  [1954/2000] Downloading: Elynia Betts...
#  [1954/2000] Downloading: Elynia Betts...
#  [1955/2000] Downloading: Elyo Grivas...
#  [1955/2000] Downloading: Elyo Grivas...
#  [1956/2000] Downloading: Elyria...
#  [1956/2000] Downloading: Elyria...
#  [1957/2000] Downloading: Elyrian...
#  [1957/2000] Downloading: Elyrian...
#  [1958/2000] Downloading: Elys Westerling...
#  [1958/2000] Downloading: Elys Westerling...
#  [1959/2000] Downloading: Em Scribbler...
#  [1959/2000] Downloading: Em Scribbler...
#  [1960/2000] Downloading: Emeline Lambert...
#  [1960/2000] Downloading: Emeline Lambert...
#  [1961/2000] Downloading: Emer McDaid...
#  [1961/2000] Downloading: Emer McDaid...
#  [1962/2000] Downloading: Emilia Blackbrow...
#  [1962/2000] Downloading: Emilia Blackbrow...
#  [1963/2000] Downloading: Emilia Clarke...
#  [1963/2000] Downloading: Emilia Clarke...
#  [1964/2000] Downloading: Emilia Umber...
#  [1964/2000] Downloading: Emilia Umber...
#  [1965/2000] Downloading: Emilio Doorgasingh...
#  [1965/2000] Downloading: Emilio Doorgasingh...
#  [1966/2000] Downloading: Emily Carey...
#  [1966/2000] Downloading: Emily Carey...
#  [1967/2000] Downloading: Emily Diamond...
#  [1967/2000] Downloading: Emily Diamond...
#  [1968/2000] Downloading: Emina Muftic...
#  [1968/2000] Downloading: Emina Muftic...
#  [1969/2000] Downloading: Emma Bryant...
#  [1969/2000] Downloading: Emma Bryant...
#  [1970/2000] Downloading: Emma D'Arcy...
#  [1970/2000] Downloading: Emma D'Arcy...
#  [1971/2000] Downloading: Emma Maguire...
#  [1971/2000] Downloading: Emma Maguire...
#  [1972/2000] Downloading: Emma O'Hara...
#  [1972/2000] Downloading: Emma O'Hara...
#  [1973/2000] Downloading: Emmett O'Riabhaigh...
#  [1973/2000] Downloading: Emmett O'Riabhaigh...
#  [1974/2000] Downloading: Emmon Cuy...
#  [1974/2000] Downloading: Emmon Cuy...
#  [1975/2000] Downloading: Emmon Massey...
#  [1975/2000] Downloading: Emmon Massey...
#  [1976/2000] Downloading: Emmon the Yellow...
#  [1976/2000] Downloading: Emmon the Yellow...
#  [1977/2000] Downloading: Empire of Ash...
#  [1977/2000] Downloading: Empire of Ash...
#  [1978/2000] Downloading: Emun Elliott...
#  [1978/2000] Downloading: Emun Elliott...
#  [1979/2000] Downloading: End a War Before It Begins...
#  [1979/2000] Downloading: End a War Before It Begins...
#  [1980/2000] Downloading: Endrew Tarth...
#  [1980/2000] Downloading: Endrew Tarth...
#  [1981/2000] Downloading: Enzo Cilenti...
#  [1981/2000] Downloading: Enzo Cilenti...
#  [1982/2000] Downloading: Eoin Duffy...
#  [1982/2000] Downloading: Eoin Duffy...
#  [1983/2000] Downloading: Eon Hunter...
#  [1983/2000] Downloading: Eon Hunter...
#  [1984/2000] Downloading: Ep. 1: A Son for a Son (with Olivia Cooke and Phia Saban)...
#  [1984/2000] Downloading: Ep. 1: A Son for a Son (with Olivia Cooke and Phia Saban)...
#  [1985/2000] Downloading: Ep. 2: Rhaenyra the Cruel (with Tom Glynn-Carney and Matthew Needham)...
#  [1985/2000] Downloading: Ep. 2: Rhaenyra the Cruel (with Tom Glynn-Carney and Matthew Needham)...
#  [1986/2000] Downloading: Ep. 3: The Burning Mill (with Bethany Antonia and director Geeta Vasant Patel)...
#  [1986/2000] Downloading: Ep. 3: The Burning Mill (with Bethany Antonia and director Geeta Vasant Patel)...
#  [1987/2000] Downloading: Ep. 4: The Red Dragon and the Gold (with Eve Best and director Alan Taylor)...
#  [1987/2000] Downloading: Ep. 4: The Red Dragon and the Gold (with Eve Best and director Alan Taylor)...
#  [1988/2000] Downloading: Ep. 5: Regent (with Ewan Mitchell and director Clare Kilner)...
#  [1988/2000] Downloading: Ep. 5: Regent (with Ewan Mitchell and director Clare Kilner)...
#  [1989/2000] Downloading: Ep. 6: Smallfolk (with Sonoya Mizuno and executive producer Sara Hess)...
#  [1989/2000] Downloading: Ep. 6: Smallfolk (with Sonoya Mizuno and executive producer Sara Hess)...
#  [1990/2000] Downloading: Ep. 7: The Red Sowing (with showrunner Ryan Condal)...
#  [1990/2000] Downloading: Ep. 7: The Red Sowing (with showrunner Ryan Condal)...
#  [1991/2000] Downloading: Ep. 8: The Queen Who Ever Was (with Showrunner Ryan Condal)...
#  [1991/2000] Downloading: Ep. 8: The Queen Who Ever Was (with Showrunner Ryan Condal)...
#  [1992/2000] Downloading: Episode 01...
#  [1992/2000] Downloading: Episode 01...
#  [1993/2000] Downloading: Episode 02...
#  [1993/2000] Downloading: Episode 02...
#  [1994/2000] Downloading: Episode 03...
#  [1994/2000] Downloading: Episode 03...
#  [1995/2000] Downloading: Episode 04...
#  [1995/2000] Downloading: Episode 04...
#  [1996/2000] Downloading: Episode 05...
#  [1996/2000] Downloading: Episode 05...
#  [1997/2000] Downloading: Episode 06...
#  [1997/2000] Downloading: Episode 06...
#  [1998/2000] Downloading: Episode 07...
#  [1998/2000] Downloading: Episode 07...
#  [1999/2000] Downloading: Episode 08...
#  [1999/2000] Downloading: Episode 08...
#  [2000/2000] Downloading: Episode 09...
#  [2000/2000] Downloading: Episode 09...
#
# ============================================================
# DOWNLOAD COMPLETE!
# ============================================================
# Successfully saved: 284 pages
# Redirects (skipped): 115 pages
# Failed: 1 pages
#
# Failed pages:
#   - Dragonkeepers
#
# Redirects logged to: GoT_files\redirects_sofie.txt
#
# Files saved in: c:\Users\sofie\OneDrive - Danmarks Tekniske Universitet\Kandidat\1. semester\02805 - Social graphs and interactions\Assignments\game_of_social_graphs_and_thrones\GoT_files
#
# ============================================================
# DOWNLOAD COMPLETE!
# ============================================================
# Successfully saved: 284 pages
# Redirects (skipped): 115 pages
# Failed: 1 pages
#
# Failed pages:
#   - Dragonkeepers
#
# Redirects logged to: GoT_files\redirects_sofie.txt
#
# Files saved in: c:\Users\sofie\OneDrive - Danmarks Tekniske Universitet\Kandidat\1. semester\02805 - Social graphs and interactions\Assignments\game_of_social_graphs_and_thrones\GoT_files

# %%
failed_pages
# Out:
# ['Dragonkeepers']
