# %%
import os
import re

from functions import get_links

# %%
FILE_PATH = 'GoT_files'

test_file = 'A Golden Crown.txt'

# f = open(os.path.join(FILE_PATH, test_file), 'r', encoding='utf-8')

# links = re.findall(r"\[{2}(?!\w{2,5}(?:-\w{2})?:)(?!File:)(?!Image:).+?\]{2}", f.read())

links = get_links(test_file)

# %%
len(links), links
# Out:
# (264,
#  ['[[Jane Espenson]]',
#   '[[David Benioff]]',
#   '[[D.B. Weiss]]',
#   '[[Daniel Minahan]]',
#   '[[298 AC]]',
#   '[[The Wolf and the Lion]]',
#   '[[You Win or You Die]]',
#   '[[Game of Thrones: Season 1|first season]]',
#   '[[Game of Thrones]]',
#   '[[HBO]]',
#   '[[Jane Espenson]]',
#   '[[David Benioff]]',
#   '[[D.B. Weiss]]',
#   '[[Daniel Minahan]]',
#   '[[Jaime Lannister]]',
#   '[[Robert Baratheon]]',
#   '[[Cersei Lannister|Queen Cersei]]',
#   '[[Tyrion Lannister|Tyrion]]',
#   "[[Hand of the King|King's Hand]]",
#   '[[House Stark]]',
#   '[[House Lannister]]',
#   '[[Arya Stark|Arya]]',
#   '[[water dance|water dancing]]',
#   '[[Syrio Forel]]',
#   '[[Jory Cassel|Jory]]',
#   '[[Renly Baratheon|Renly]]',
#   '[[Barristan Selmy]]',
#   '[[Lancel Lannister]]',
#   '[[Small Council]]',
#   '[[Riverlands]]',
#   '[[Gregor Clegane]]',
#   '[[House Tully]]',
#   '[[Beric Dondarrion]]',
#   '[[Knighthood|knights]]',
#   '[[Pycelle]]',
#   '[[Casterly Rock]]',
# ...
